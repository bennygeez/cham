# %%
# !nvidia-smi
# Out:
# Sun Jan 19 16:47:02 2025
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.183.01             Driver Version: 535.183.01   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 3090        Off | 00000000:01:00.0 Off |                  N/A |
# |  0%   36C    P5              35W / 370W |    680MiB / 24576MiB |     35%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.5 🚀 Python-3.12.2 torch-2.4.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3090, 24260MiB)
# Setup complete ✅ (20 CPUs, 62.6 GB RAM, 248.4/273.1 GB disk)

# %%
from ultralytics import YOLO
from IPython.display import Image

# %%
# !pip3 install --upgrade "jax[cuda12]"==0.4.28

# %%
pwd
# Out:
# '/home/avidmech'

# %%
# !yolo task=detect mode=train data=/home/avidmech/Basketball_large_dataset/data.yaml model="yolov9e.pt" epochs=150 imgsz=640 batch=16 optimizer="NAdam"
# Out:
# New https://pypi.org/project/ultralytics/8.3.63 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.5 🚀 Python-3.12.2 torch-2.4.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3090, 24260MiB)
# ...

# %% [markdown]
# # **Yolo9e**

# %% [markdown]
# # ***Training for 12 hours***

# %%
# !yolo task=detect mode=val model="/home/avidmech/runs/detect/train/weights/best.pt" data=/home/avidmech/Basketball_large_dataset/data.yaml
# Out:
# Ultralytics 8.3.5 🚀 Python-3.12.2 torch-2.4.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3090, 24260MiB)
# YOLOv9e summary (fused): 705 layers, 53,206,431 parameters, 0 gradients, 169.5 GFLOPs
# val: Scanning /home/avidmech/Basketball_large_dataset/valid/labels.cache... 812
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        812       3330      0.894       0.89      0.936      0.742
#                   ball        689        802      0.915      0.877      0.927      0.713
#                   made         48         48      0.975      0.829      0.931      0.751
#                 person        579       1771      0.888      0.899      0.949      0.727
#                    rim        527        543       0.98      0.961      0.987      0.837
#                  shoot        166        166      0.711      0.886      0.889      0.682
# Speed: 0.3ms preprocess, 16.6ms inference, 0.0ms loss, 0.6ms postprocess per image
# ...

# %% [markdown]
# # ***Training for 4 hours***

# %%
# !yolo task=detect mode=val model="/home/avidmech/runs2/detect/train/weights/best.pt" data=/home/avidmech/Basketball_large_dataset/data.yaml
# Out:
# Ultralytics 8.3.5 🚀 Python-3.12.2 torch-2.4.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3090, 24260MiB)
# YOLOv9e summary (fused): 705 layers, 53,206,431 parameters, 0 gradients, 169.5 GFLOPs
# val: Scanning /home/avidmech/Basketball_large_dataset/valid/labels.cache... 812
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        812       3330      0.884      0.909      0.937      0.731
#                   ball        689        802      0.908      0.903      0.921      0.708
#                   made         48         48      0.976      0.865      0.932      0.728
#                 person        579       1771      0.853      0.924      0.948      0.712
#                    rim        527        543      0.963      0.964      0.983      0.822
#                  shoot        166        166      0.721      0.892      0.898      0.686
# Speed: 0.3ms preprocess, 16.3ms inference, 0.0ms loss, 0.6ms postprocess per image
# ...

# %% [markdown]
# # ***YOLo11***

# %%
1!yolo task=detect mode=val model="/home/avidmech/runs1/detect/train/weights/best.pt" data=/home/avidmech/basketball_rim/data.yaml
# Out:
# Ultralytics 8.3.5 🚀 Python-3.12.2 torch-2.4.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3090, 24260MiB)
# YOLO11x summary (fused): 464 layers, 56,833,954 parameters, 0 gradients, 194.4 GFLOPs
# val: Scanning /home/avidmech/basketball_rim/valid/labels.cache... 358 images, 0
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        358        736      0.892      0.853      0.889      0.588
#                   ball          2          4          1      0.714      0.769      0.356
#                 basket          3          6      0.878          1      0.995      0.441
#             basketball        173        188      0.853      0.864      0.901      0.752
#                 people        103        282      0.722      0.684      0.737      0.566
#                    rim        234        249      0.899      0.924      0.936      0.823
#                  score          7          7          1      0.933      0.995      0.592
# ...

# %%
# !yolo task=detect mode=train data=/home/avidmech/Basketball_large_dataset/data.yaml model="yolo11x.pt" epochs=150 imgsz=640 batch=16 optimizer="NAdam"

# %% [markdown]
# # ***Right side video object detection***

# %%
import cv2

from ultralytics import YOLO

# Load the YOLO11 model
model = YOLO("/home/avidmech/runs2/detect/train/weights/best.pt")

# Open the video file
video_path = "/home/avidmech/rr4.mp4"
cap = cv2.VideoCapture(video_path)

# Loop through the video frames
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()

    if success:
        # Run YOLO11 tracking on the frame, persisting tracks between frames
        results = model.track(frame, persist=True)

        # Visualize the results on the frame
        annotated_frame = results[0].plot()

        # Display the annotated frame
        cv2.imshow("YOLO11 Tracking", annotated_frame)

        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        # Break the loop if the end of the video is reached
        break

# Release the video capture object and close the display window
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # ***Left side view object detection***

# %%
import cv2

from ultralytics import YOLO

# Load the YOLO11 model
model = YOLO("/home/avidmech/runs3/detect/train/weights/best.pt")

# Open the video file
video_path = "/home/avidmech/left4.mp4"
cap = cv2.VideoCapture(video_path)

# Loop through the video frames
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()

    if success:
        # Run YOLO11 tracking on the frame, persisting tracks between frames
        results = model.track(frame, persist=True)

        # Visualize the results on the frame
        annotated_frame = results[0].plot()

        # Display the annotated frame
        cv2.imshow("YOLO11 Tracking", annotated_frame)

        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        # Break the loop if the end of the video is reached
        break

# Release the video capture object and close the display window
cap.release()
cv2.destroyAllWindows()
